# %%
# 导入操作系统接口模块，用于执行与操作系统相关的操作
import os

# 导入请求模块，用于发送HTTP请求
import requests

# 导入时间模块，用于处理时间相关的操作
import time

# 导入系统模块，用于访问系统特定的参数和函数
import sys

# 导入JSON处理模块，用于解析和处理JSON数据
import json

# 从Google API客户端库中导入构建函数，用于创建API服务对象
from googleapiclient.discovery import build

# 从Google API客户端库中导入HTTP错误处理模块，用于处理API调用时可能发生的HTTP错误
from googleapiclient.errors import HttpError

# 保存日志
import logging

# %%
# api
API_KEY = 'AIzaSyDFphGybwWRO5xx2c6W669sGT4UCrwwiPA'

# 使用YouTube Data API构建一个YouTube服务对象
# 这里的'youtube'是API服务名称，'v3'是API版本，developerKey是开发者密钥
youtube = build('youtube', 'v3', developerKey=API_KEY)

# 设置代理（用的不是真正的VPN的话，CMD ping不通google.com）
# 见：https://www.v2ex.com/t/877527
# 代理软件是不通 icmp 的，也就是 ping 不通的。
# 需要在Python中显示地配置代理
os.environ['HTTP_PROXY'] = 'http://127.0.0.1:7890'
os.environ['HTTPS_PROXY'] = 'http://127.0.0.1:7890'

# %%
# 搜索视频
# 当调用 youtube.search().list() 方法时，API 返回一个包含搜索结果的 JSON 响应。

def search_videos(query,video_durations=['medium'],max_results=50):
    # query -> main()
    # max_results 此处不需要设置
    all_video_ids = []
    
    for duration in video_durations:
        request = youtube.search().list(
            part='snippet',  # 返回的数据部分，包含基本信息
            q=query,
            type='video',
            videoDuration=duration,  # 分别搜索短、中、长视频
            maxResults=max_results,  # 需要前100个视频，而单次请求最多只能返回50个，因此需要多次请求。
            order='relevance'  # 按相关性排序
        )
        response = request.execute()
        video_ids = [item['id']['videoId'] for item in response.get('items', [])]
        all_video_ids.extend(video_ids)
    
    return list(set(all_video_ids))  # 去重并返回视频唯一标识符列表

# %%
# 测试代码
def test_search_videos():
    query = 'black myth wukong'
    duration = 'medium'
    max_results = 1
    
    print(f"Searching for videos with query: '{query}', duration: '{duration}', max_results: {max_results}")
    
    request = youtube.search().list(
        part='snippet',
        q=query,
        type='video',
        videoDuration=duration,
        maxResults=max_results,
        order='relevance'
    )
    
    response = request.execute()
    
    # 打印完整的JSON响应
    print("Full JSON Response:")
    print(json.dumps(response, ensure_ascii=False, indent=4))
    
    # 提取并打印视频ID列表
    video_ids = [item['id']['videoId'] for item in response.get('items', [])]
    print("\nExtracted Video IDs:")
    print(video_ids)

test_search_videos()
# Out:
# Searching for videos with query: 'black myth wukong', duration: 'medium', max_results: 1
# Full JSON Response:
# {
#     "kind": "youtube#searchListResponse",
#     "etag": "W17ZIJ8ZulMIQJgkIbpP9iBRB0o",
#     "nextPageToken": "CAEQAA",
#     "regionCode": "SG",
#     "pageInfo": {
#         "totalResults": 670096,
#         "resultsPerPage": 1
#     },
#     "items": [
#         {
#             "kind": "youtube#searchResult",
#             "etag": "3_ZmpM2DeAavg0wFwepv3kdwHW0",
#             "id": {
#                 "kind": "youtube#video",
#                 "videoId": "333otzqZq3w"
#             },
#             "snippet": {
#                 "publishedAt": "2024-12-18T23:49:30Z",
#                 "channelId": "UCzF5oxzeidHOZzy4KK5nxCQ",
#                 "title": "Black Myth Wukong Just Got The Biggest Update Ever...",
#                 "description": "Black Myth Wukong update (Black Myth Wukong Patch while we wait for black myth wukong DLC) Like the video? Subscribe now: ...",
#                 "thumbnails": {
#                     "default": {
#                         "url": "https://i.ytimg.com/vi/333otzqZq3w/default.jpg",
#                         "width": 120,
#                         "height": 90
#                     },
#                     "medium": {
#                         "url": "https://i.ytimg.com/vi/333otzqZq3w/mqdefault.jpg",
#                         "width": 320,
#                         "height": 180
#                     },
#                     "high": {
#                         "url": "https://i.ytimg.com/vi/333otzqZq3w/hqdefault.jpg",
#                         "width": 480,
#                         "height": 360
#                     }
#                 },
#                 "channelTitle": "JorRaptor",
#                 "liveBroadcastContent": "none",
#                 "publishTime": "2024-12-18T23:49:30Z"
#             }
#         }
#     ]
# }
#
# Extracted Video IDs:
# ['333otzqZq3w']

# %%
def get_video_comments(video_id, max_comments=200, max_replies=20):
    comments = []
    request = youtube.commentThreads().list(
        part='snippet,replies', # 获取评论的基本信息和回复。
        videoId=video_id,
        textFormat='plainText', # 选择 'plainText' 可以避免处理HTML标签。但缺点是爬不了emoji，可能会对情感分析有些许影响（也不一定）
        maxResults=min(50,max_comments), # 获取请求返回的最大结果数量。最大返回数为50，如果要求的max_comments比这个还小，就设定为max_comments。
        order='relevance'  # 可以是 'time' 或 'relevance'。选择 'time' 按时间顺序排列，选择 'relevance' 按相关性排列。
    )
    while len(comments) < max_comments:
        response = request.execute()     # 执行请求并获取响应
        for item in response.get('items', []):  # 遍历每个评论线程
            comment_snippet = item['snippet']['topLevelComment']['snippet']
            if comment_snippet['likeCount'] > -1:  # 忽略0赞评论 -> 不忽略了，设置为-1
                comment_data = {
                    'comment_id': comment_snippet['authorChannelId']['value'],  # 发布者ID
                    'text': comment_snippet['textDisplay'],                     # 评论文本
                    'likes': comment_snippet['likeCount'],                      # 获赞数
                    'replies': []
                }
                if 'replies' in item and len(item['replies']['comments']) > 0:  # 处理回复
                    replies = item['replies']['comments'][:max_replies]  # 限制回复数量为20条
                    for reply_item in replies:
                        reply_snippet = reply_item['snippet']
                        # 回复的话0赞也要
                        comment_data['replies'].append({
                            'reply_id': reply_snippet['authorChannelId']['value'],  # 回复发布者ID
                            'reply_text': reply_snippet['textDisplay'],             # 回复文本
                            'reply_likes': reply_snippet['likeCount']              # 回复获赞数
                        })
                comments.append(comment_data)
        if 'nextPageToken' in response:  # 检查是否有更多页
            request = youtube.commentThreads().list_next(request, response)  # 请求下一页
        else:
            break
    return comments[:max_comments]

# %%
# 测试代码
def test_get_video_comments():
    video_id = '333otzqZq3w'
    print(f"Fetching comments for video ID: {video_id}")
    
    try:
        response = get_video_comments(video_id)
        
        # 打印完整的JSON响应
        print("Full JSON Response:")
        print(json.dumps(response, ensure_ascii=False, indent=4))
    
    except Exception as e:
        print(f"An error occurred: {e}")

test_get_video_comments()
# Out:
# Fetching comments for video ID: 333otzqZq3w
# Full JSON Response:
# [
#     {
#         "comment_id": "UCtlZVpaJuul3oF7YoqW3fYQ",
#         "text": "This is one of those games i wish i could replay for the first time again 😢 Its so damn good! WE NEED A BIG DLC LIKE ER: SOTET!",
#         "likes": 28,
#         "replies": [
#             {
#                 "reply_id": "UCpce7MP8fJmnTLOUwSO6V8Q",
#                 "reply_text": "guarantee were gonna get one",
#                 "reply_likes": 0
#             },
#             {
#                 "reply_id": "UCWJEKqwq1reXuvPaDmB0PzQ",
#                 "reply_text": "Try elden ring, dark souls, sekiro, god of war",
#                 "reply_likes": 0
#             }
#         ]
#     },
#     {
#         "comment_id": "UCd4KEX4C4aV7ATKuvoWFYFw",
#         "text": "They added a lot of stuff sheesh",
#         "likes": 10,
#         "replies": []
#     },
#     {
#         "comment_id": "UCw8-QrfRfQ0KIvBmSIc5jcg",
#         "text": "Most deserved GOTY.",
#         "likes": 31,
#         "replies": []
#     },
#     {
#         "comment_id": "UCqQ0zm97GU5q_Uzp05R4t1Q",
#         "text": "Time to go back to the game that should have won GOTY!!",
#         "likes": 10,
#         "replies": [
#             {
#                 "reply_id": "UCKht5-zHKdmoTmEqCheSRDA",
#                 "reply_text": "Astro bot had the women and children vote we were totally outnumbered 😂😂😂 never stood chance my wife and 2 daughters were the audience I’m only one screaming wukong 😂😂😂",
#                 "reply_likes": 4
#             },
#             {
#                 "reply_id": "UCvRGpWNKL50Vg8aTvcnZ42A",
#                 "reply_text": "​@@IzzyDaBoiWonda😂😂😂 FACTS!!",
#                 "reply_likes": 0
#             }
#         ]
#     },
#     {
#         "comment_id": "UCtDQ2ihAf5MYxbj1_Urs7bA",
#         "text": "Erlang, throwing me outside the barrier is the only reason that I was able to beat him the very first time",
#         "likes": 13,
#         "replies": [
#             {
#                 "reply_id": "UCcFMymoeJ05d04iVdjH7YYA",
#                 "reply_text": "Samehere 😂",
#                 "reply_likes": 0
#             }
#         ]
#     },
#     {
#         "comment_id": "UC5dSIB8ZR-ARYFuidt--pmQ",
#         "text": "It's crazy ...to know bmw didn't win goty",
#         "likes": 3,
#         "replies": [
#             {
#                 "reply_id": "UClch0DI2NtSVjPyHLmKxjPg",
#                 "reply_text": "But they produce pretty good cars!",
#                 "reply_likes": 3
#             }
#         ]
#     },
#     {
#         "comment_id": "UCL_R3B47g9ul9TViG-Fuv6g",
#         "text": "No buff to wukong stance or anything in general is a missed opportunity. You get extremely weak in this game after 3 playthroughs",
#         "likes": 3,
#         "replies": [
#             {
#                 "reply_id": "UC3nLmX3ZFyudZt5XJDtVdug",
#                 "reply_text": "Update added a curio after you beat wukong in gaunlet, much longer time and damage for wukong stance after equipped",
#                 "reply_likes": 1
#             }
#         ]
#     },
#     {
#         "comment_id": "UCFFojGHMl8d3j18LLVcMKFw",
#         "text": "This is like a DLC for free",
#         "likes": 6,
#         "replies": [
#             {
#                 "reply_id": "UChcXUmfmmhpSZRmFCezF5UA",
#                 "reply_text": "It's a micro-transaction for free.",
#                 "reply_likes": 4
#             }
#         ]
#     },
#     {
#         "comment_id": "UCs2xWnegZymcPizTSnwvEUw",
#         "text": "help, I can't seem to equip old weapons that were previously crafted. It just brings be to the ui making me craft them again. Anyone else???",
#         "likes": 1,
#         "replies": [
#             {
#                 "reply_id": "UCUwsnbgMrSax0e0RYUPvB3A",
#                 "reply_text": "That part",
#                 "reply_likes": 0
#             }
#         ]
#     },
#     {
#         "comment_id": "UCumhGtpwbuJgHLwwFzkBIvA",
#         "text": "This game needs to come to Xbox already. I don’t know why they haven’t done that yet. Is it a time to exclusive? I can’t remember if it was or not.",
#         "likes": 8,
#         "replies": [
#             {
#                 "reply_id": "UCCs2JqcWPUINGfX0PtX3_7A",
#                 "reply_text": "Nope, they just straight up. Said they’re not doing it.",
#                 "reply_likes": 3
#             },
#             {
#                 "reply_id": "UCMniMLscUuHNiRySgbb7fzQ",
#                 "reply_text": "From what I remember I believe there was problems with the series S version. Of course it didn't stop people spreading the rumour Sony paid for a timed exclusive release.",
#                 "reply_likes": 0
#             },
#             {
#                 "reply_id": "UCj9vN14vI5GEX5q5jv2ugbQ",
#                 "reply_text": "@@calijack2006 so it’s not coming to Xbox?",
#                 "reply_likes": 0
#             },
#             {
#                 "reply_id": "UCCs2JqcWPUINGfX0PtX3_7A",
#                 "reply_text": "@@logicrules5793 nope",
#                 "reply_likes": 0
#             },
#             {
#                 "reply_id": "UCPknpWXsN9VAQbfNdWGPw3w",
#                 "reply_text": "@@logicrules5793 It's coming, just be patient for the optimization struggle on Xbox",
#                 "reply_likes": 0
#             }
#         ]
#     },
#     {
#         "comment_id": "UC2KgwUERJraQ15jV2R16NVw",
#         "text": "Time for new run",
#         "likes": 1,
#         "replies": []
#     },
#     {
#         "comment_id": "UCLfRc-mNY6Ljv0PFHfp0g0w",
#         "text": "Woohoo. Always watch the videos with you voicing them. Just not a fan of the others. Respectfully !! But I get why you do it",
#         "likes": 8,
#         "replies": [
#             {
#                 "reply_id": "UCRFMoSwOaRnOEnj_1SAVVsA",
#                 "reply_text": "don't tear down others to compliment others. he's been doing it for a long time, go back to his first videos and tell me the quality is the same. let them settle in.",
#                 "reply_likes": 1
#             },
#             {
#                 "reply_id": "UCJ52ir1FKeZwQ2kEHc8oehg",
#                 "reply_text": "I like his awkward voice. Theres something to it lmao.",
#                 "reply_likes": 0
#             }
#         ]
#     },
#     {
#         "comment_id": "UCIHer_XGFF_OFU3ciEry2Bg",
#         "text": "That might get me to play Black Myth Wukong , till AC Shadows will come out february 14",
#         "likes": 7,
#         "replies": [
#             {
#                 "reply_id": "UCzF5oxzeidHOZzy4KK5nxCQ",
#                 "reply_text": "You should, my favorite game of the year!",
#                 "reply_likes": 10
#             },
#             {
#                 "reply_id": "UCgd3QZzIET_CXtfyXrzMarQ",
#                 "reply_text": "Any ideas when we can pre order ac shadows digital on PS5?",
#                 "reply_likes": 0
#             },
#             {
#                 "reply_id": "UCM7vBmAzJxoSxfHXBgQKnfg",
#                 "reply_text": "Why AC Shadows is DEI crap",
#                 "reply_likes": 1
#             },
#             {
#                 "reply_id": "UCxghffQ0YI-O1HbnI3LcvXg",
#                 "reply_text": "​@@curtisrohling5852 you haven't even played the game",
#                 "reply_likes": 1
#             },
#             {
#                 "reply_id": "UCq0uUZFIAYOLLiRC5LTW70g",
#                 "reply_text": "​@@curtisrohling5852Because it has a black protagonist or do you know something we don't?",
#                 "reply_likes": 0
#             }
#         ]
#     },
#     {
#         "comment_id": "UCj9vN14vI5GEX5q5jv2ugbQ",
#         "text": "This sounds good and all, but when is it coming to Xbox?",
#         "likes": 1,
#         "replies": []
#     },
#     {
#         "comment_id": "UCypqQdqATelVYOWxMC4gWgw",
#         "text": "Awesome can’t wait for dlc 👍🫡",
#         "likes": 3,
#         "replies": []
#     },
#     {
#         "comment_id": "UCGMNsgbV3GfTAZCKwk16w6g",
#         "text": "When do you guy think they'll release it on xbox?",
#         "likes": 1,
#         "replies": []
#     },
#     {
#         "comment_id": "UCVSOSaam1igsxMmhDr9rjbg",
#         "text": "hi JorRaptor",
#         "likes": 1,
#         "replies": []
#     },
#     {
#         "comment_id": "UC7OC4qHPlS-ltZImIzZLlSw",
#         "text": "My GOTY got a new update 🎉 Awesome 😂 tga can play astrobotts ❤",
#         "likes": 2,
#         "replies": []
#     },
#     {
#         "comment_id": "UCS_YEU0ozHx3oS-rKI_-sZw",
#         "text": "Nerfing in a single player game is wild",
#         "likes": 2,
#         "replies": [
#             {
#                 "reply_id": "UCcQLk_-eOXBRXPmis2AmHJw",
#                 "reply_text": "Not really, single player still needs to have balance",
#                 "reply_likes": 1
#             }
#         ]
#     },
#     {
#         "comment_id": "UCceYiMkfuVJJKJvqc0snheg",
#         "text": "Did they fix the insane broken enemy design or no?they wouldn’t won goty if they actually play tested it first",
#         "likes": 1,
#         "replies": [
#             {
#                 "reply_id": "UCZonIdqDSXb71YyUkfkQsZQ",
#                 "reply_text": "There is no broken enemy design. Just get better or don't.",
#                 "reply_likes": 1
#             },
#             {
#                 "reply_id": "UCM7Llbgqa2aV7rOHNxgbygw",
#                 "reply_text": "What broken enemy design?",
#                 "reply_likes": 0
#             },
#             {
#                 "reply_id": "UCgajHWKIV3cuBmomSHv7IMQ",
#                 "reply_text": "​@@ChocolateEffigy hey look!\nanother \"git gud\" guy\n\n*here's a lil trophy for being such an awesome player on Black Myth Wukong* 🏆",
#                 "reply_likes": 1
#             },
#             {
#                 "reply_id": "UCceYiMkfuVJJKJvqc0snheg",
#                 "reply_text": "@@ChocolateEffigy yall jobless people literally all say the same thing 😂you have 0 excuse not to be good when you have 24 hours everyday to play 🤦🏾this game isn’t enjoyable first play through at all unless you have time to practice",
#                 "reply_likes": 2
#             },
#             {
#                 "reply_id": "UCceYiMkfuVJJKJvqc0snheg",
#                 "reply_text": "@@danfoster6757 the dog shit camera, hitboxes, mechanics 😂😂I can go on ….this game has countless fights in the game where the enemy can jump over your head and the camera starts have a seizure trying to track them",
#                 "reply_likes": 0
#             }
#         ]
#     },
#     {
#         "comment_id": "UCsmKsZhnSMB26BeCyPqVWLQ",
#         "text": "This is old news bro. You’re a week old. Why is nobody calling him out for this?",
#         "likes": 2,
#         "replies": []
#     },
#     {
#         "comment_id": "UCHJNmoh-gnlMjm5Iw885d1g",
#         "text": "Viewers really dropped off since you tried to promote Shadows.",
#         "likes": 15,
#         "replies": [
#             {
#                 "reply_id": "UCZonIdqDSXb71YyUkfkQsZQ",
#                 "reply_text": "Bro just making stuff up 💀",
#                 "reply_likes": 11
#             },
#             {
#                 "reply_id": "UC4jCGXujz-AFPkrZcYPufTg",
#                 "reply_text": "Ok",
#                 "reply_likes": 1
#             },
#             {
#                 "reply_id": "UCb49cUaVYoT2mRKh_BAcLqA",
#                 "reply_text": "And intergalactic too !",
#                 "reply_likes": 5
#             },
#             {
#                 "reply_id": "UCkMm9Lf2-jgVZ9Nemcg1bCg",
#                 "reply_text": "No need for this comment.",
#                 "reply_likes": 4
#             },
#             {
#                 "reply_id": "UC1DTkNrZGMs1uRu7tOKGpLw",
#                 "reply_text": "Yet here you are",
#                 "reply_likes": 5
#             }
#         ]
#     },
#     {
#         "comment_id": "UCt9iOsLU7_Xh75ErNL4Ul2w",
#         "text": "Meh content…. Kinda wish the dlc would bring more to the table",
#         "likes": 1,
#         "replies": [
#             {
#                 "reply_id": "UCaRCdERBl5wMO0LY757Iz7w",
#                 "reply_text": "This is no DLC my bro",
#                 "reply_likes": 4
#             },
#             {
#                 "reply_id": "UCCs2JqcWPUINGfX0PtX3_7A",
#                 "reply_text": "This is just an update, not the DLC",
#                 "reply_likes": 1
#             }
#         ]
#     },
#     {
#         "comment_id": "UCldndbqcwgW2pe9l41yY3eA",
#         "text": "Is the developer still crying because he didn't win game of the year?",
#         "likes": 2,
#         "replies": [
#             {
#                 "reply_id": "UC8-aRBUaHmtPUCpSB2Gyi_A",
#                 "reply_text": "Lol and where did he cry? Just be glad your little kiddie platforming game won goty 😂",
#                 "reply_likes": 5
#             },
#             {
#                 "reply_id": "UCldndbqcwgW2pe9l41yY3eA",
#                 "reply_text": "@@donsmemory4 are you living under a rock? its known that he cried,. its on video :)",
#                 "reply_likes": 1
#             },
#             {
#                 "reply_id": "UCw8-QrfRfQ0KIvBmSIc5jcg",
#                 "reply_text": "You must be 6 if you think Astro deserved it over Wukong 😂",
#                 "reply_likes": 6
#             },
#             {
#                 "reply_id": "UCldndbqcwgW2pe9l41yY3eA",
#                 "reply_text": "@@silveriver9 wukong is the definition of a Mid game, i platinumed it on PS5 and that game aint special",
#                 "reply_likes": 1
#             },
#             {
#                 "reply_id": "UCw8-QrfRfQ0KIvBmSIc5jcg",
#                 "reply_text": "@ Loved it enough to pump in all those hours and to get platinum 😂. Also immediately clicked and left a comment on a Wukong video as soon as it was uploaded 👏😁",
#                 "reply_likes": 6
#             }
#         ]
#     },
#     {
#         "comment_id": "UC5Ufyr8JekDOum0XwCN1c2Q",
#         "text": "Still doesn't deserve Game of the Year",
#         "likes": 1,
#         "replies": [
#             {
#                 "reply_id": "UCw8-QrfRfQ0KIvBmSIc5jcg",
#                 "reply_text": "Why you here then? 🤦‍♂️. The awkward moment when the hater realizes he is the No.1 fan 😁",
#                 "reply_likes": 6
#             },
#             {
#                 "reply_id": "UCxn7VvqG10ec5-WMS4Xd68A",
#                 "reply_text": "...",
#                 "reply_likes": 0
#             },
#             {
#                 "reply_id": "UCgajHWKIV3cuBmomSHv7IMQ",
#                 "reply_text": "@@silveriver9 \"mimiimiiii your opinion hurts my lil feelings\" lookin ahh 🤦‍♂🤦‍♂",
#                 "reply_likes": 0
#             },
#             {
#                 "reply_id": "UCCs2JqcWPUINGfX0PtX3_7A",
#                 "reply_text": "neither did Astro bot rebirth deserved it a lot more",
#                 "reply_likes": 1
#             },
#             {
#                 "reply_id": "UCYs44xCaPqoyhyht4Nw0fzQ",
#                 "reply_text": "Yea just stop",
#                 "reply_likes": 0
#             }
#         ]
#     }
# ]

# %%
# 数据存储
def save_to_json(data, file_path): # 保存数据到json文件
    with open(file_path, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

# %%
# 构建本地路径测试
data_dir = os.path.join(os.getcwd(), 'data')
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# 主程序
def main():
    # 设置查询参数
    query = 'black myth wukong'
    max_videos = 100    # 视频爬取最大数量
    max_comments = 200  # 每条视频评论爬取最大数量
    
    # 搜索视频
    videos = []
    video_duration = ['medium']

    print(f"Searching for videos with query: {query}")
    while len(videos) < max_videos:
        new_videos = search_videos(query, video_durations=video_duration, max_results=min(50, max_videos - len(videos)))
        if not new_videos:
            break
        videos.extend(new_videos)
    print(f"Found {len(videos)} videos.")

    # 获取评论
    all_comments = []
    comment_index = 1

    print(f"Fetching comments.")
    for video_id in videos:
        print(f"Fetching comments for video ID: {video_id}")
        comments = get_video_comments(video_id, max_comments=max_comments)
        print(f'{len(comments)} comments fetched.')
        for comment in comments:
            all_comments.append({
                'index': comment_index,
                'video_id': video_id,
                'comment_id': comment['comment_id'],
                'text': comment['text'],
                'likes': comment['likes'],
                'replies': comment['replies']
            })
            comment_index += 1
    print("Comments fetched.")

    # 构建数据目录的路径，基于当前工作目录
    print("Saving data to disk...")
    data_dir = os.path.join(os.getcwd(), 'data')
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)

    # 将 all_comments 数据保存到 data 目录下的 comments.json 文件中
    save_to_json(all_comments, os.path.join(data_dir, 'comments.json'))
    print("Data saved.")

# %%
if __name__ == '__main__':
    try:
        main()
    except HttpError as e:
        print(f"An HTTP error {e.resp.status} occurred:\n{e.content}")
# Out:
# Searching for videos with query: black myth wukong
# Found 100 videos.
# Fetching comments.
# Fetching comments for video ID: 2PHqki02vUI
# 200 comments fetched.
# Fetching comments for video ID: yc5BE-TzK5k
# 200 comments fetched.
# Fetching comments for video ID: qOsDHymg_Yo
# 200 comments fetched.
# Fetching comments for video ID: LRkf0R6VDRA
# 200 comments fetched.
# Fetching comments for video ID: 3mgNkc0XlyY
# 200 comments fetched.
# Fetching comments for video ID: kyp-nCNGkz8
# 200 comments fetched.
# Fetching comments for video ID: 35DvC36BZYI
# 200 comments fetched.
# Fetching comments for video ID: JPmC0R_hnjs
# 200 comments fetched.
# Fetching comments for video ID: lUVI2KIJw2c
# 200 comments fetched.
# Fetching comments for video ID: qLBy5WJ4FI4
# 46 comments fetched.
# Fetching comments for video ID: Ky3ZPaL31H0
# 200 comments fetched.
# Fetching comments for video ID: GYXbNX5_2QE
# 10 comments fetched.
# Fetching comments for video ID: fY4JCD8guR8
# 200 comments fetched.
# Fetching comments for video ID: YpF3ZRRo0n4
# 80 comments fetched.
# Fetching comments for video ID: J0446DH_zLs
# 68 comments fetched.
# Fetching comments for video ID: WgcIOrE_CS8
# 200 comments fetched.
# Fetching comments for video ID: sujB9P1i4ME
# 136 comments fetched.
# Fetching comments for video ID: X80eccLymmw
# 54 comments fetched.
# Fetching comments for video ID: Vh9WonecZ7M
# 84 comments fetched.
# Fetching comments for video ID: aulEh6qZXG8
# 200 comments fetched.
# Fetching comments for video ID: _mAnlVXtDD8
# 200 comments fetched.
# Fetching comments for video ID: oMsDHtpg5y8
# 102 comments fetched.
# Fetching comments for video ID: 333otzqZq3w
# 37 comments fetched.
# Fetching comments for video ID: W4an2zq8i5Q
# 200 comments fetched.
# Fetching comments for video ID: WDU1RnHDymQ
# 90 comments fetched.
# Fetching comments for video ID: mRMuvSVV0hE
# 28 comments fetched.
# Fetching comments for video ID: bzyMLoSwYvk
# 200 comments fetched.
# Fetching comments for video ID: EzGfIZHIef4
# 50 comments fetched.
# Fetching comments for video ID: pnSsgRJmsCc
# 200 comments fetched.
# Fetching comments for video ID: Us9tcd_Xvuk
# 200 comments fetched.
# Fetching comments for video ID: kPLnD7U1lPo
# 200 comments fetched.
# Fetching comments for video ID: 7pHLUOyM9sM
# 124 comments fetched.
# Fetching comments for video ID: w_13U6FrK4U
# 200 comments fetched.
# Fetching comments for video ID: mL-XG0MM8pw
# 200 comments fetched.
# Fetching comments for video ID: TMzqLJ3QAtA
# 107 comments fetched.
# Fetching comments for video ID: C0S-xlDY0dQ
# 200 comments fetched.
# Fetching comments for video ID: UTUw9bqrFNE
# 200 comments fetched.
# Fetching comments for video ID: YKjYAsWsNvw
# 155 comments fetched.
# Fetching comments for video ID: GIV7aN9cQYY
# 200 comments fetched.
# Fetching comments for video ID: BuWXXyzfmXo
# 5 comments fetched.
# Fetching comments for video ID: uA3gcHj0jDs
# 118 comments fetched.
# Fetching comments for video ID: nAee0-sNwMw
# 200 comments fetched.
# Fetching comments for video ID: DmS5XOnhoR4
# 200 comments fetched.
# Fetching comments for video ID: 3AVR0ofbW7E
# 200 comments fetched.
# Fetching comments for video ID: JouHyAui5OU
# 93 comments fetched.
# Fetching comments for video ID: VLnywm2XgJg
# 200 comments fetched.
# Fetching comments for video ID: n_uZ5ziqS7Y
# 9 comments fetched.
# Fetching comments for video ID: JoUu4iMJLh0
# 9 comments fetched.
# Fetching comments for video ID: zpObqm0a50s
# 200 comments fetched.
# Fetching comments for video ID: oU2rTXVQiG0
# 11 comments fetched.
# Fetching comments for video ID: 2PHqki02vUI
# 200 comments fetched.
# Fetching comments for video ID: qOsDHymg_Yo
# 200 comments fetched.
# Fetching comments for video ID: bCCMEuAG1oI
# 200 comments fetched.
# Fetching comments for video ID: ilbEu5ULAIc
# 200 comments fetched.
# Fetching comments for video ID: LRkf0R6VDRA
# 200 comments fetched.
# Fetching comments for video ID: 3mgNkc0XlyY
# 200 comments fetched.
# Fetching comments for video ID: kyp-nCNGkz8
# 200 comments fetched.
# Fetching comments for video ID: 35DvC36BZYI
# 200 comments fetched.
# Fetching comments for video ID: FHZ7lAhPPpM
# 46 comments fetched.
# Fetching comments for video ID: YaG2nr3eThg
# 200 comments fetched.
# Fetching comments for video ID: JPmC0R_hnjs
# 200 comments fetched.
# Fetching comments for video ID: 5ZN0lebBoZY
# 200 comments fetched.
# Fetching comments for video ID: lUVI2KIJw2c
# 200 comments fetched.
# Fetching comments for video ID: Ky3ZPaL31H0
# 200 comments fetched.
# Fetching comments for video ID: xWMrq2FH3LU
# 119 comments fetched.
# Fetching comments for video ID: 1dRnYIhIZFk
# 200 comments fetched.
# Fetching comments for video ID: t05rY-_ES4Y
# 135 comments fetched.
# Fetching comments for video ID: oRLhCxC886o
# 200 comments fetched.
# Fetching comments for video ID: 1E4pQXWQVSY
# 167 comments fetched.
# Fetching comments for video ID: aulEh6qZXG8
# 200 comments fetched.
# Fetching comments for video ID: X80eccLymmw
# 54 comments fetched.
# Fetching comments for video ID: WgcIOrE_CS8
# 200 comments fetched.
# Fetching comments for video ID: _mAnlVXtDD8
# 200 comments fetched.
# Fetching comments for video ID: _zn756E6xMs
# 200 comments fetched.
# Fetching comments for video ID: oMsDHtpg5y8
# 102 comments fetched.
# Fetching comments for video ID: 333otzqZq3w
# 37 comments fetched.
# Fetching comments for video ID: W4an2zq8i5Q
# 200 comments fetched.
# Fetching comments for video ID: WDU1RnHDymQ
# 90 comments fetched.
# Fetching comments for video ID: -eQM0K-Ak8w
# 200 comments fetched.
# Fetching comments for video ID: KLsdwWrJOjA
# 200 comments fetched.
# Fetching comments for video ID: bzyMLoSwYvk
# 200 comments fetched.
# Fetching comments for video ID: EzGfIZHIef4
# 50 comments fetched.
# Fetching comments for video ID: UMMLnsbDKRM
# 200 comments fetched.
# Fetching comments for video ID: pnSsgRJmsCc
# 200 comments fetched.
# Fetching comments for video ID: Us9tcd_Xvuk
# 200 comments fetched.
# Fetching comments for video ID: NS_3GiK1lO8
# 200 comments fetched.
# Fetching comments for video ID: xDuDKJ366Jg
# 47 comments fetched.
# Fetching comments for video ID: -pPbA7UgW7s
# 200 comments fetched.
# Fetching comments for video ID: w_13U6FrK4U
# 200 comments fetched.
# Fetching comments for video ID: mL-XG0MM8pw
# 200 comments fetched.
# Fetching comments for video ID: asSNCYmMqEI
# 200 comments fetched.
# Fetching comments for video ID: YKjYAsWsNvw
# 155 comments fetched.
# Fetching comments for video ID: nAee0-sNwMw
# 200 comments fetched.
# Fetching comments for video ID: DmS5XOnhoR4
# 200 comments fetched.
# Fetching comments for video ID: 3AVR0ofbW7E
# 200 comments fetched.
# Fetching comments for video ID: 2lfXX8KeYpo
# 200 comments fetched.
# Fetching comments for video ID: VLnywm2XgJg
# 200 comments fetched.
# Fetching comments for video ID: DKCXfTmEt9A
# 137 comments fetched.
# Fetching comments for video ID: JqpZdKwmqao
# 200 comments fetched.
# Fetching comments for video ID: oU2rTXVQiG0
# 11 comments fetched.
# Comments fetched.
# Saving data to disk...
# Data saved.
